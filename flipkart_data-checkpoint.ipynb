# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\shubh\Downloads\Flipkart E-Commerse dataset\flipkart_com-ecommerce_sample.csv")

# %%
df.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df.tail()
# Out:
#                                 uniq_id            crawl_timestamp  \
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
# 20000                               NaN                        NaN
# 20001                               NaN                        NaN
#
#                                              product_url  \
# 19997  http://www.flipkart.com/elite-collection-mediu...
# 19998  http://www.flipkart.com/elite-collection-mediu...
# 19999  http://www.flipkart.com/elite-collection-mediu...
# 20000                                                NaN
# 20001                                                NaN
#
#                                   product_name  \
# 19997  Elite Collection Medium Acrylic Sticker
# 19998  Elite Collection Medium Acrylic Sticker
# 19999  Elite Collection Medium Acrylic Sticker
# ...

# %%
df.shape
# Out:
# (20002, 15)

# %%
df.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# uniq_id                       2
# crawl_timestamp               2
# product_url                   2
# product_name                  2
# product_category_tree         2
# pid                           2
# retail_price                 80
# discounted_price             80
# image                         5
# is_FK_Advantage_product       2
# description                   4
# product_rating                2
# overall_rating                2
# brand                      5866
# product_specifications       16
# dtype: int64

# %%
df = df.drop('product_rating ',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = df.drop('product_rating ',axis=1,inplace=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
# ...

# %%
df.shape
# Out:
# (20002, 15)

# %%
df = df.drop(columns=['product_rating'])

# %%
df.shape
# Out:
# (20002, 14)

# %%
df = df.drop(columns=['overall_rating'])

# %%
df.shape
# Out:
# (20002, 13)

# %%
df.isnull().sum()
# Out:
# uniq_id                       2
# crawl_timestamp               2
# product_url                   2
# product_name                  2
# product_category_tree         2
# pid                           2
# retail_price                 80
# discounted_price             80
# image                         5
# is_FK_Advantage_product       2
# description                   4
# brand                      5866
# product_specifications       16
# dtype: int64

# %%
df['brand'] = df['brand'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# uniq_id                     2
# crawl_timestamp             2
# product_url                 2
# product_name                2
# product_category_tree       2
# pid                         2
# retail_price               80
# discounted_price           80
# image                       5
# is_FK_Advantage_product     2
# description                 4
# brand                       0
# product_specifications     16
# dtype: int64

# %%
df = df.dropna(subset=['retail_price','discounted_price'])

# %%
df.isnull().sum()
# Out:
# uniq_id                     0
# crawl_timestamp             0
# product_url                 0
# product_name                0
# product_category_tree       0
# pid                         0
# retail_price                0
# discounted_price            0
# image                       3
# is_FK_Advantage_product     0
# description                 2
# brand                       0
# product_specifications     12
# dtype: int64

# %%
df.shape
# Out:
# (19922, 13)

# %%
df = df.dropna(subset=['image','description','product_specifications'])

# %%
df.isnull().sum()
# Out:
# uniq_id                    0
# crawl_timestamp            0
# product_url                0
# product_name               0
# product_category_tree      0
# pid                        0
# retail_price               0
# discounted_price           0
# image                      0
# is_FK_Advantage_product    0
# description                0
# brand                      0
# product_specifications     0
# dtype: int64

# %%
df.shape
# Out:
# (19905, 13)

# %%
import os
os.listdir()
# Out:
# ['.android',
#  '.config',
#  '.copilot',
#  '.cursor',
#  '.emulator_console_auth_token',
#  '.gitconfig',
#  '.gradle',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.lesshst',
#  '.matplotlib',
#  '.nbi',
#  '.node_repl_history',
#  '.ssh',
#  '.th-client',
#  '.vscode',
#  '.vscode-shared',
#  'airline reservation system.java',
#  'ajeetyadav index.html',
#  'AndroidStudioProjects',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'customer_shopping_behavior.csv',
#  'Desktop',
#  'djdjoidwodwdw.html',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Flipkart E-Commerse Dataset.ipynb',
#  'flipkart.ipynb',
#  'flipkart_cleaned.csv',
#  'flipkart_data.ipynb',
#  'Hr Analyst.ipynb',
#  'html',
#  'html.com',
#  'IdeaProjects',
#  'index',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'netflix_cleaned_data.csv',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
# ...

# %%
import os
os.listdir()
# Out:
# ['.android',
#  '.config',
#  '.copilot',
#  '.cursor',
#  '.emulator_console_auth_token',
#  '.gitconfig',
#  '.gradle',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.lesshst',
#  '.matplotlib',
#  '.nbi',
#  '.node_repl_history',
#  '.ssh',
#  '.th-client',
#  '.vscode',
#  '.vscode-shared',
#  'airline reservation system.java',
#  'ajeetyadav index.html',
#  'AndroidStudioProjects',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'customer_shopping_behavior.csv',
#  'Desktop',
#  'djdjoidwodwdw.html',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Flipkart E-Commerse Dataset.ipynb',
#  'flipkart.ipynb',
#  'flipkart_cleaned.csv',
#  'flipkart_data.ipynb',
#  'Hr Analyst.ipynb',
#  'html',
#  'html.com',
#  'IdeaProjects',
#  'index',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'netflix_cleaned_data.csv',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\shubh
